# %% [markdown]
# <a href="https://colab.research.google.com/github/BooEiEi/data_viz_2022/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # เตรียมข้อมูล

# %% [markdown]
# ####Import data

# %%
import pandas as pd  # เรียกใช้คำว่า pd แทน pandas ได้
import os

# %%
from google.colab import drive  # pandas ใช้จัดการไฟล์ต่าง ๆ ที่เป็นตาราง เช่น excel .csv
drive.mount('/content/drive') # ถ้าไฟล์ใน gg drive ไม่หาย ก็จะยังสามารถรันข้อมูลได้
path = '/content/drive/My Drive/project_dataviz'
# Out:
# Mounted at /content/drive

# %%
data_covid1 = pd.read_csv(os.path.join(path, 'confirmed-cases.csv'))
data_covid2 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-120864.csv'))
data_covid3 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-271064.csv'))
data_covid4 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-280265.csv'))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ##confirmed-cases 1
# ข้อมูล confirmed-cases ตั้งแต่วันแรก - 11/08/2021

# %%
data_covid1
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985     11/8/2021     10/8/2021  หญิง   8.0   ปี    Thailand
# 816985  816986     11/8/2021     10/8/2021   ชาย  14.0   ปี    Thailand
# 816986  816987     11/8/2021     10/8/2021   ชาย  59.0   ปี    Thailand
# 816987  816988     11/8/2021     10/8/2021  หญิง  34.0   ปี    Thailand
# 816988  816989     11/8/2021     10/8/2021  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 816984               สระแก้ว
# 816985               สระแก้ว
# 816986               สระแก้ว
# 816987               สระแก้ว
# 816988               สระแก้ว
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 816984                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816985                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816986  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...           สระแก้ว
# 816987                                              อื่นๆ     กรุงเทพมหานคร
# 816988                                              อื่นๆ   พระนครศรีอยุธยา
#
#        district_of_onset
# 0                    NaN
# 1                    NaN
# 2                  เมือง
# 3                    NaN
# 4                    NaN
# ...                  ...
# 816984           ตาพระยา
# 816985           ตาพระยา
# 816986        อรัญประเทศ
# 816987       บางขุนเทียน
# 816988             อุทัย
#
# [816989 rows x 11 columns]

# %% [markdown]
# ###ตรวจสอบ Missing

# %%
data_covid1.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ###แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
data_covid1_updated = data_covid1.fillna(value={'Notified date':'ไม่มีข้อมูล','sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})  # เลข -99 คือการใสเลขที่ไม่ซ้ำจากอันเดิม  #ตัวแปรชื่อ value  #แทนค่า missing ด้วย 'ไม่รู้'
data_covid1_updated.head()
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1     12/1/2020   ไม่มีข้อมูล  หญิง  61.0   ปี       China
# 1    2     17/1/2020   ไม่มีข้อมูล  หญิง  74.0   ปี       China
# 2    3     22/1/2020   ไม่มีข้อมูล  หญิง  73.0   ปี    Thailand
# 3    4     22/1/2020   ไม่มีข้อมูล   ชาย  68.0   ปี       China
# 4    5     24/1/2020   ไม่มีข้อมูล  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0       ไม่มีข้อมูล
# 1       ไม่มีข้อมูล
# 2             เมือง
# 3       ไม่มีข้อมูล
# 4       ไม่มีข้อมูล

# %%
data_covid1_updated.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                       True
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ###แทน age ด้วยค่า mean

# %%
data_covid_mean1 = data_covid1_updated.fillna(value={'age':data_covid1['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_mean1.isnull().any()  #คอลัมน์ sex ไม่มี missing
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
data_covid_mean1
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020   ไม่มีข้อมูล  หญิง  61.0   ปี       China
# 1            2     17/1/2020   ไม่มีข้อมูล  หญิง  74.0   ปี       China
# 2            3     22/1/2020   ไม่มีข้อมูล  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020   ไม่มีข้อมูล   ชาย  68.0   ปี       China
# 4            5     24/1/2020   ไม่มีข้อมูล  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985     11/8/2021     10/8/2021  หญิง   8.0   ปี    Thailand
# 816985  816986     11/8/2021     10/8/2021   ชาย  14.0   ปี    Thailand
# 816986  816987     11/8/2021     10/8/2021   ชาย  59.0   ปี    Thailand
# 816987  816988     11/8/2021     10/8/2021  หญิง  34.0   ปี    Thailand
# 816988  816989     11/8/2021     10/8/2021  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 816984               สระแก้ว
# 816985               สระแก้ว
# 816986               สระแก้ว
# 816987               สระแก้ว
# 816988               สระแก้ว
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 816984                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816985                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816986  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...           สระแก้ว
# 816987                                              อื่นๆ     กรุงเทพมหานคร
# 816988                                              อื่นๆ   พระนครศรีอยุธยา
#
#        district_of_onset
# 0            ไม่มีข้อมูล
# 1            ไม่มีข้อมูล
# 2                  เมือง
# 3            ไม่มีข้อมูล
# 4            ไม่มีข้อมูล
# ...                  ...
# 816984           ตาพระยา
# 816985           ตาพระยา
# 816986        อรัญประเทศ
# 816987       บางขุนเทียน
# 816988             อุทัย
#
# [816989 rows x 11 columns]

# %% [markdown]
# ##confirmed-cases 2
# ตั้งแต่วันที่ 12/08/2021 - วันที่ 25/10/2021

# %%
data_covid2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ###ตรวจสอบ Missing

# %%
data_covid2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ###แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
data_covid2_updated = data_covid2.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})  # เลข -99 คือการใสเลขที่ไม่ซ้ำจากอันเดิม  #ตัวแปรชื่อ value  #แทนค่า missing ด้วย 'ไม่รู้'
data_covid2_updated.head()
# Out:
#       No. announce_date Notified date   sex   age Unit nationality  \
# 0  816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1  816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2  816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3  816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4  816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
#
#   province_of_isolation                                         risk  \
# 0              เชียงราย                                        อื่นๆ
# 1              เชียงราย                                        อื่นๆ
# 2              เชียงราย                                        อื่นๆ
# 3              เชียงราย                                        อื่นๆ
# 4              เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset
# 0       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1       ไม่มีข้อมูล       ไม่มีข้อมูล
# 2       ไม่มีข้อมูล       ไม่มีข้อมูล
# 3       ไม่มีข้อมูล       ไม่มีข้อมูล
# 4       ไม่มีข้อมูล       ไม่มีข้อมูล

# %% [markdown]
# ###แทน age ด้วยค่า mean

# %%
data_covid_mean2 = data_covid2_updated .fillna(value={'age':data_covid2['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_mean2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
data_covid_mean2
# Out:
#              No. announce_date Notified date   sex   age Unit  nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี     Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี     Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี     Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี     Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี     Thailand
# ...          ...           ...           ...   ...   ...  ...          ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี  ไม่มีข้อมูล
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี  ไม่มีข้อมูล
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี  ไม่มีข้อมูล
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0             ไม่มีข้อมูล       ไม่มีข้อมูล
# 1             ไม่มีข้อมูล       ไม่มีข้อมูล
# 2             ไม่มีข้อมูล       ไม่มีข้อมูล
# 3             ไม่มีข้อมูล       ไม่มีข้อมูล
# 4             ไม่มีข้อมูล       ไม่มีข้อมูล
# ...                   ...               ...
# 1042163       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042164       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042165       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042166       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042167       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ##confirmed-cases 3
# ตั้งแต่วันที่ 26/10/2021 - วันที่ 27/02/2022

# %%
data_covid3
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  Unnamed: 11
# 0                   ลำปาง        เมืองลำปาง          NaN
# 1                   ลำปาง        เมืองลำปาง          NaN
# 2                   ลำปาง          ห้างฉัตร          NaN
# 3                   ลำปาง          ห้างฉัตร          NaN
# 4                   ลำปาง        เมืองลำปาง          NaN
# ...                   ...               ...          ...
# 1010454               NaN               NaN          NaN
# 1010455               NaN               NaN          NaN
# 1010456               NaN               NaN          NaN
# 1010457               NaN               NaN          NaN
# 1010458               NaN               NaN          NaN
#
# [1010459 rows x 12 columns]

# %% [markdown]
# ###ตรวจสอบ Missing

# %%
data_covid3.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# Unnamed: 11               True
# dtype: bool

# %% [markdown]
# จะเห็นได้ว่า ข้อมูล data_covid3 ยังมีค่า Missing อยู่

# %% [markdown]
# ###แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
data_covid3_updated = data_covid3.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล','Unnamed: 11':'ไม่มีข้อมูล'})  # เลข -99 คือการใสเลขที่ไม่ซ้ำจากอันเดิม  #ตัวแปรชื่อ value  #แทนค่า missing ด้วย 'ไม่รู้'
data_covid3_updated.head()
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1  1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2  1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3  1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4  1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
#
#   province_of_isolation                                           risk  \
# 0                 ลำปาง                                          อื่นๆ
# 1                 ลำปาง                                          อื่นๆ
# 2                 ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                 ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                 ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset  Unnamed: 11
# 0             ลำปาง        เมืองลำปาง  ไม่มีข้อมูล
# 1             ลำปาง        เมืองลำปาง  ไม่มีข้อมูล
# 2             ลำปาง          ห้างฉัตร  ไม่มีข้อมูล
# 3             ลำปาง          ห้างฉัตร  ไม่มีข้อมูล
# 4             ลำปาง        เมืองลำปาง  ไม่มีข้อมูล

# %% [markdown]
# ###แทน age ด้วยค่า mean

# %%
data_covid_mean3 = data_covid3_updated.fillna(value={'age':data_covid1['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_mean3.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# Unnamed: 11              False
# dtype: bool

# %%
data_covid_mean3
# Out:
#              No. announce_date Notified date   sex       age         Unit  \
# 0        1859158    26/10/2021    25/10/2021   ชาย      20.0           ปี
# 1        1859159    26/10/2021    25/10/2021  หญิง      42.0           ปี
# 2        1859160    26/10/2021    25/10/2021  หญิง      33.0           ปี
# 3        1859161    26/10/2021    25/10/2021  หญิง      52.0           ปี
# 4        1859162    26/10/2021    25/10/2021  หญิง      84.0           ปี
# ...          ...           ...           ...   ...       ...          ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย  35.67704  ไม่มีข้อมูล
# 1010455  2869613     27/2/2022     26/2/2022   ชาย  35.67704  ไม่มีข้อมูล
# 1010456  2869614     27/2/2022     26/2/2022   ชาย  35.67704  ไม่มีข้อมูล
# 1010457  2869615     27/2/2022     26/2/2022   ชาย  35.67704  ไม่มีข้อมูล
# 1010458  2869616     27/2/2022     26/2/2022   ชาย  35.67704  ไม่มีข้อมูล
#
#          nationality province_of_isolation  \
# 0           Thailand                 ลำปาง
# 1           Thailand                 ลำปาง
# 2           Thailand                 ลำปาง
# 3           Thailand                 ลำปาง
# 4           Thailand                 ลำปาง
# ...              ...                   ...
# 1010454  ไม่มีข้อมูล         กรุงเทพมหานคร
# 1010455  ไม่มีข้อมูล         กรุงเทพมหานคร
# 1010456  ไม่มีข้อมูล               ปัตตานี
# 1010457  ไม่มีข้อมูล               ปัตตานี
# 1010458  ไม่มีข้อมูล               ปัตตานี
#
#                                                   risk province_of_onset  \
# 0                                                อื่นๆ             ลำปาง
# 1                                                อื่นๆ             ลำปาง
# 2        ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว             ลำปาง
# 3        ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว             ลำปาง
# 4          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             ลำปาง
# ...                                                ...               ...
# 1010454                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 1010455                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 1010456                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 1010457                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 1010458                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
#
#         district_of_onset  Unnamed: 11
# 0              เมืองลำปาง  ไม่มีข้อมูล
# 1              เมืองลำปาง  ไม่มีข้อมูล
# 2                ห้างฉัตร  ไม่มีข้อมูล
# 3                ห้างฉัตร  ไม่มีข้อมูล
# 4              เมืองลำปาง  ไม่มีข้อมูล
# ...                   ...          ...
# 1010454       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010455       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010456       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010457       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010458       ไม่มีข้อมูล  ไม่มีข้อมูล
#
# [1010459 rows x 12 columns]

# %% [markdown]
# ##confirmed-cases 4
# ตั้งแต่วันที่ 26/10/2021 - วันที่ 27/02/2022

# %%
data_covid4
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %% [markdown]
# ###ตรวจสอบ Missing

# %%
data_covid4.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# จะเห็นได้ว่า ข้อมูล data_covid2 ยังมีค่า Missing อยู่

# %% [markdown]
# ###แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
data_covid4_updated = data_covid4.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})  
data_covid4_updated.head()
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1  2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2  2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3  2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4  2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
#
#   province_of_isolation                                         risk  \
# 0                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset
# 0             พะเยา        เมืองพะเยา
# 1             พะเยา        เมืองพะเยา
# 2             พะเยา        เมืองพะเยา
# 3             พะเยา        เมืองพะเยา
# 4             พะเยา        เมืองพะเยา

# %% [markdown]
# ###แทน age ด้วยค่า mean

# %%
data_covid_mean4 = data_covid4_updated .fillna(value={'age':data_covid4['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_mean4.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ข้อมูล data_covid3 ไม่มีค่า missing แล้ว

# %%
data_covid_mean4
# Out:
#             No. announce_date Notified date   sex        age         Unit  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.000000           ปี
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.000000           ปี
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.000000           ปี
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.000000           ปี
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.000000           ปี
# ...         ...           ...           ...   ...        ...          ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433549  3303166     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433550  3303167     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433551  3303168     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433552  3303169     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
#
#         nationality province_of_isolation  \
# 0          Thailand                 พะเยา
# 1          Thailand                 พะเยา
# 2          Thailand                 พะเยา
# 3          Thailand                 พะเยา
# 4          Thailand                 พะเยา
# ...             ...                   ...
# 433548  ไม่มีข้อมูล         กรุงเทพมหานคร
# 433549  ไม่มีข้อมูล         กรุงเทพมหานคร
# 433550  ไม่มีข้อมูล         กรุงเทพมหานคร
# 433551  ไม่มีข้อมูล                 สงขลา
# 433552  ไม่มีข้อมูล                 สงขลา
#
#                                                risk province_of_onset  \
# 0       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 1       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 3       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 4       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...                                             ...               ...
# 433548                             ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433549                             ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433550                             ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433551                             ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433552                             ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
#
#        district_of_onset
# 0             เมืองพะเยา
# 1             เมืองพะเยา
# 2             เมืองพะเยา
# 3             เมืองพะเยา
# 4             เมืองพะเยา
# ...                  ...
# 433548       ไม่มีข้อมูล
# 433549       ไม่มีข้อมูล
# 433550       ไม่มีข้อมูล
# 433551       ไม่มีข้อมูล
# 433552       ไม่มีข้อมูล
#
# [433553 rows x 11 columns]

# %% [markdown]
# #รวมตาราง

# %% [markdown]
# ###รวมตาราง data_covid1 และ data_covid2

# %%
covid = pd.concat([data_covid_mean1 ,data_covid_mean2])  #รวมตาราง
covid
# Out:
#              No. announce_date Notified date   sex   age Unit  nationality  \
# 0              1     12/1/2020   ไม่มีข้อมูล  หญิง  61.0   ปี        China
# 1              2     17/1/2020   ไม่มีข้อมูล  หญิง  74.0   ปี        China
# 2              3     22/1/2020   ไม่มีข้อมูล  หญิง  73.0   ปี     Thailand
# 3              4     22/1/2020   ไม่มีข้อมูล   ชาย  68.0   ปี        China
# 4              5     24/1/2020   ไม่มีข้อมูล  หญิง  66.0   ปี        China
# ...          ...           ...           ...   ...   ...  ...          ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี  ไม่มีข้อมูล
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี  ไม่มีข้อมูล
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี  ไม่มีข้อมูล
#
#         province_of_isolation                              risk  \
# 0               กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1               กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                      นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3               กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                     นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                       ...                               ...
# 1042163         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0           กรุงเทพมหานคร       ไม่มีข้อมูล
# 1           กรุงเทพมหานคร       ไม่มีข้อมูล
# 2                  นครปฐม             เมือง
# 3           กรุงเทพมหานคร       ไม่มีข้อมูล
# 4           กรุงเทพมหานคร       ไม่มีข้อมูล
# ...                   ...               ...
# 1042163       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042164       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042165       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042166       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042167       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [1859157 rows x 11 columns]

# %% [markdown]
# ###รวมตาราง data_covid3 และ data_covid4

# %%
covid1 = pd.concat([data_covid_mean3 ,data_covid_mean4])  #รวมตาราง
covid1
# Out:
#             No. announce_date Notified date   sex        age         Unit  \
# 0       1859158    26/10/2021    25/10/2021   ชาย       20.0           ปี
# 1       1859159    26/10/2021    25/10/2021  หญิง       42.0           ปี
# 2       1859160    26/10/2021    25/10/2021  หญิง       33.0           ปี
# 3       1859161    26/10/2021    25/10/2021  หญิง       52.0           ปี
# 4       1859162    26/10/2021    25/10/2021  หญิง       84.0           ปี
# ...         ...           ...           ...   ...        ...          ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433549  3303166     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433550  3303167     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433551  3303168     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433552  3303169     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
#
#         nationality province_of_isolation  \
# 0          Thailand                 ลำปาง
# 1          Thailand                 ลำปาง
# 2          Thailand                 ลำปาง
# 3          Thailand                 ลำปาง
# 4          Thailand                 ลำปาง
# ...             ...                   ...
# 433548  ไม่มีข้อมูล         กรุงเทพมหานคร
# 433549  ไม่มีข้อมูล         กรุงเทพมหานคร
# 433550  ไม่มีข้อมูล         กรุงเทพมหานคร
# 433551  ไม่มีข้อมูล                 สงขลา
# 433552  ไม่มีข้อมูล                 สงขลา
#
#                                                  risk province_of_onset  \
# 0                                               อื่นๆ             ลำปาง
# 1                                               อื่นๆ             ลำปาง
# 2       ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว             ลำปาง
# 3       ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว             ลำปาง
# 4         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             ลำปาง
# ...                                               ...               ...
# 433548                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433549                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433550                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433551                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433552                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
#
#        district_of_onset  Unnamed: 11
# 0             เมืองลำปาง  ไม่มีข้อมูล
# 1             เมืองลำปาง  ไม่มีข้อมูล
# 2               ห้างฉัตร  ไม่มีข้อมูล
# 3               ห้างฉัตร  ไม่มีข้อมูล
# 4             เมืองลำปาง  ไม่มีข้อมูล
# ...                  ...          ...
# 433548       ไม่มีข้อมูล          NaN
# 433549       ไม่มีข้อมูล          NaN
# 433550       ไม่มีข้อมูล          NaN
# 433551       ไม่มีข้อมูล          NaN
# 433552       ไม่มีข้อมูล          NaN
#
# [1444012 rows x 12 columns]

# %% [markdown]
# ###รวมตาราง covid และ covid1

# %%
confirm = pd.concat([covid ,covid1])  #รวมตาราง
confirm
# Out:
#             No. announce_date Notified date   sex        age         Unit  \
# 0             1     12/1/2020   ไม่มีข้อมูล  หญิง       61.0           ปี
# 1             2     17/1/2020   ไม่มีข้อมูล  หญิง       74.0           ปี
# 2             3     22/1/2020   ไม่มีข้อมูล  หญิง       73.0           ปี
# 3             4     22/1/2020   ไม่มีข้อมูล   ชาย       68.0           ปี
# 4             5     24/1/2020   ไม่มีข้อมูล  หญิง       66.0           ปี
# ...         ...           ...           ...   ...        ...          ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433549  3303166     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433550  3303167     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433551  3303168     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
# 433552  3303169     18/3/2022     17/3/2022  หญิง  37.136383  ไม่มีข้อมูล
#
#         nationality province_of_isolation                              risk  \
# 0             China         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1             China         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          Thailand                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3             China         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4             China               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...             ...                   ...                               ...
# 433548  ไม่มีข้อมูล         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549  ไม่มีข้อมูล         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550  ไม่มีข้อมูล         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551  ไม่มีข้อมูล                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552  ไม่มีข้อมูล                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset Unnamed: 11
# 0          กรุงเทพมหานคร       ไม่มีข้อมูล         NaN
# 1          กรุงเทพมหานคร       ไม่มีข้อมูล         NaN
# 2                 นครปฐม             เมือง         NaN
# 3          กรุงเทพมหานคร       ไม่มีข้อมูล         NaN
# 4          กรุงเทพมหานคร       ไม่มีข้อมูล         NaN
# ...                  ...               ...         ...
# 433548       ไม่มีข้อมูล       ไม่มีข้อมูล         NaN
# 433549       ไม่มีข้อมูล       ไม่มีข้อมูล         NaN
# 433550       ไม่มีข้อมูล       ไม่มีข้อมูล         NaN
# 433551       ไม่มีข้อมูล       ไม่มีข้อมูล         NaN
# 433552       ไม่มีข้อมูล       ไม่มีข้อมูล         NaN
#
# [3303169 rows x 12 columns]

# %% [markdown]
# #แก้ไข้ชื่อจังหวัดใน column province_of_onset

# %%
set(confirm['province_of_onset'])
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำเพงเพชร',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขอนแก่่น',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'ขานุวรลักษณ์บุรี',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จ.สุราษฎร์ธานี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชลบุรี\xa0',
#  'ชลบุุรี',
#  'ชอนแก่น',
#  'ชัยนาถ',
#  'ชัยนาท',
#  'ชัยบาดาล',
#  'ชัยภูมิ',
#  'ชัยภูมิ\xa0',
#  'ชุมพร',
#  'ชุุมพร',
#  'ชุุุมพร',
#  'ดอนมดแดง',
#  'ดินแดง',
#  'ตรัง',
#  'ตรััง',
#  'ตราด',
#  'ตราด\xa0',
#  'ตาก',
#  'ตากใบ',
#  'ต่างจังหวัด',
#  'ทุ่งเสลี่ยม',
#  'ท้ายบ้าน',
#  'ธารโต',
#  'นคนปฐม',
#  'นคปฐม',
#  'นครนปฐม',
#  'นครนาชสีมา',
#  'นครนายก',
#  'นครปฐม',
#  'นครปฐม\xa0',
#  'นครปบม',
#  'นครพนม',
#  'นครพนม\xa0',
#  'นครยายก',
#  'นครราขสีมา',
#  'นครราชธานี',
#  'นครราชศรีมา',
#  'นครราชสสีมา',
#  'นครราชสีมา',
#  'นครราชสีมา ลพบุรี',
#  'นครราชสีมา\xa0',
#  'นครศรธรรมราช',
#  'นครศรี',
#  'นครศรีธรมมราช',
#  'นครศรีธรมราช',
#  'นครศรีธรรมราข',
#  'นครศรีธรรมราช',
#  'นครศรีฯ',
#  'นครศรีีธรรมราช',
#  'นครศร๊ธรรมราช',
#  'นครศร๊ะรรมราช',
#  'นครสรรค์',
#  'นครสรีธรรมราช',
#  'นครสวรรค',
#  'นครสวรรค์',
#  'นครสวรรค์\xa0',
#  'นครสีธรรมราช',
#  'นครฯ',
#  'นคราชสีมา',
#  'นครีศรีธรรมราช',
#  'นตรนายก',
#  'นตรปฐม',
#  'นนทบุรี',
#  'นนทบุรี\xa0',
#  'นนทบุุรี',
#  'นนทุบรี',
#  'นนทุรี',
#  'นนมบุรี',
#  'นรศรีธรรมราช',
#  'นราธิวาส',
#  'นราธิวาส\u200b',
#  'นราธฺวาส',
#  'นอกเขต',
#  'นาราธิวาส',
#  'นาวัง',
#  'น่าน',
#  'น่าน/ฉะเชิงเทรา',
#  'บางกรวย',
#  'บางกะปิ',
#  'บางนา',
#  'บางปะอิน',
#  'บางละมุง',
#  'บางศรีเมือง',
#  'บางเพียง',
#  'บึงกาฬ',
#  'บึงโขงหลง',
#  'บุรีรัมภ์',
#  'บุรีรัมย์',
#  'บุรีรัมย์\xa0',
#  'บุรีรัยม์',
#  'บุรีรีมย์',
#  'บ้านหลวง',
#  'ปจ',
#  'ปทึมธานี',
#  'ปทุทธานี',
#  'ปทุมฑานี',
#  'ปทุมทานี',
#  'ปทุมธาน',
#  'ปทุมธานี',
#  'ปทุมธานี.',
#  'ปทุมธานี\xa0',
#  'ปทุมธานีี',
#  'ปทุมาธานี',
#  'ปทุุมธานี',
#  'ปธุมธานี',
#  'ปมุมธานี',
#  'ประจวนคีรีขันธ็',
#  'ประจวบ',
#  'ประจวบคิรีขันธ์',
#  'ประจวบคีรขันธ์',
#  'ประจวบคีรขัันธ์',
#  'ประจวบคีรีขัน',
#  'ประจวบคีรีขันธื',
#  'ประจวบคีรีขันธฺ',
#  'ประจวบคีรีขันธ์',
#  'ประจวบคีรีขันธ์\xa0',
#  'ประจวบคีรีขันธ์์',
#  'ประจวบคีรีขัันธ์',
#  'ประจวบคีีรีขันธ์',
#  'ประจวบฯ',
#  'ประทุมธานี',
#  'ประเทศกัมพูชา',
#  'ปราจีนบุรี',
#  'ปราจีบุรี',
#  'ปลวกแดง',
#  'ปลายพระยา',
#  'ปอยเปต',
#  'ปัตตนรี',
#  'ปัตตานนี',
#  'ปัตตานี',
#  'ปัตตานีี',
#  'ปัว',
#  'ปััตตานี',
#  'ปุทมธานี',
#  'ป่าโมก',
#  'พม่า',
#  'พรหมพิราม',
#  'พระนครศรียุธยา',
#  'พระนครศรีอยุทธยา',
#  'พระนครศรีอยุทยา',
#  'พระนครศรีอยุธยา',
#  'พระนครศรีอยุธยา\xa0',
#  'พะเยา',
#  'พังงา',
#  'พัทยา',
#  'พัทลุง',
#  'พัทลุุง',
#  'พัังงา',
#  'พิจิตร',
#  'พิษณุโลก',
#  'พิษณุโลก\xa0',
#  'พิษณูโลก',
#  'ฟินแลนด์',
#  'ภาษีเจริญ',
#  'ภุเก็ต',
#  'ภูุเก็ต',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'ภูเก็็ต',
#  'ภูเพียง',
#  'มหาสาคาม',
#  'มหาสารคาม',
#  'มาเลเซีย',
#  'มุกดาหาร',
#  'มุกาดหาร',
#  'ยะลา',
#  'ยานนาวา',
#  'ยโสธร',
#  'ร.จ.จ.นราธิวาส',
#  'รอ',
#  'ระนอง',
#  'ระบุ',
#  'ระยอง',
#  'ระยอง\xa0',
#  'ระอยง',
#  'ราชบบุรี',
#  'ราชบุรี',
#  'ราชบุรีี',
#  'ราชบุรี\u200b',
#  'ราชุรี',
#  'ราชเทวี',
#  'ร้องกวาง',
#  'ร้อยเอ็ด',
#  'ลบุรี',
#  'ลพบุรี',
#  'ลพบุรี.',
#  'ลพบุรี\xa0',
#  'ลอง',
#  'ลาดกระบัง',
#  'ลาดพร้าว',
#  'ลาว',
#  'ลำปาง',
#  'ลำพูน',
#  'ลำพูน\u200b',
#  'ลำพููน',
#  'ลำลูกกา',
#  'วังชิ้น',
#  'วังทอง',
#  'วิเศษชัยชาญ',
#  'ศรีษะสะเกษ',
#  'ศรีษะเกษ',
#  'ศรีสระเกษ',
#  'ศรีสะเกษ',
#  'ศีรสะเกษ',
#  'สกลนคร',
#  'สครสวรรค์',
#  'สงขลา',
#  'สงขลา\u200b',
#  'สตูล',
#  'สถานที่ทำงาน',
#  'สพรรณบุรี',
#  'สมถทรปราการ',
#  'สมทรสงคราม',
#  'สมทรสาคร',
#  'สมุครปราการ',
#  'สมุครสาคร',
#  'สมุท',
#  'สมุทปราการ',
#  'สมุทรปรากร',
#  'สมุทรปรากรร',
#  'สมุทรปรากา',
#  'สมุทรปราการ',
#  'สมุทรปราการ\xa0',
#  'สมุทรศาคร',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สมุทรสาคร\xa0',
#  'สมุทรสาคา',
#  'สมุทรสาคาร',
#  'สมุทรสาทร',
#  'สมุทรสารคร',
#  'สมุทราปราการ',
#  'สมุทราสาคร',
#  'สมุทสงคราม',
#  'สมุทสาคร',
#  'สมุย',
#  'สมุุทรปราการ',
#  'สมุุทรสงคราม',
#  'สมุุทรสาคร',
#  'สระก้ว',
#  'สระบุรี',
#  'สระบุรี\xa0',
#  'สระแก้ว',
#  'สรินทร์',
#  'สวิสเซอร์แลนด์',
#  'สอง',
#  'สองแคว',
#  'สะพานสูง',
#  'สะแก้ว',
#  'สัตหีบ',
#  'สัมผัสผู้ป่วยยืนยัน COVID20',
#  'สามุทรสาคร',
#  'สารคาม',
#  'สารภี',
#  'สิงห์บุรี',
#  'สิงห์บุรี\xa0',
#  'สุทรปราการ',
#  'สุพรรญบุรี',
#  'สุพรรณบุรั',
#  'สุพรรณบุรี',
#  'สุพรรณบุรี\xa0',
#  'สุมทรปราการ',
#  'สุมทรสาคร',
#  'สุมุทรปราการ',
#  'สุมุทรสาคร',
#  'สุระบุรี',
#  'สุราษ',
#  'สุราษฎณ์ธานี',
#  'สุราษฎธานี',
#  'สุราษฎร์',
#  'สุราษฎร์ธานี',
#  'สุราษฎร์ฯ',
#  'สุราษฎร์์ธานี',
#  'สุราษฎ์ธานี',
#  'สุราษฏร์ธานี',
#  'สุราษธานี',
#  'สุราษร์ฎธานี',
#  'สุราษร์ธานี',
#  'สุราษฯ',
#  'สุรินทรื',
#  'สุรินทร์',
#  'สุรินทร์ 32150',
#  'สุรินทร์,รีสะเกษ',
#  'สุรินทร์\xa0',
#  'สุริมทร์',
#  'สุริะแก้ว',
#  'สุวรรณภูมิ',
#  'สุุพรรณบุรี',
#  'สุุราษฎร์ธานี',
#  'สุุราษฏร์ธานี',
#  'สุุราษฯ',
#  'สุุรินทร์',
#  'สุุุโขทัย',
#  'สุโขทับ',
#  'สุโขทัย',
#  'สุโขทัย\xa0',
#  'สูงเม่น',
#  'หนวงบัวลำภู',
#  'หนองคาย',
#  'หนองงคาย',
#  'หนองบัวภู',
#  'หนองบัวลำพูน',
#  'หนองบัวลำภู',
#  'หนองบัวลําภู',
#  'หนองบััวลำภู',
#  'หนองม่วงไข่',
#  'หนอบัวลำภู',
#  'หลายจังหวัด',
#  'หัวหิน',
#  'ห้วยขวาง',
#  'อยุทธยา',
#  'อยุธยา',
#  'อยุุธยา',
#  'อำนาจเจริญ',
#  'อำนาจเจิญ',
#  'อำนาญเจริญ',
#  'อำนาเจริญ',
#  'อิสราเอล',
#  'อุดธานี',
#  'อุดร',
#  'อุดรธาณี',
#  'อุดรธานี',
#  'อุดรธานี\xa0',
#  'อุดรธานีี',
#  'อุดรราชธานี',
#  'อุตรดิตถ์',
#  'อุตรดิตถ์\xa0',
#  'อุตรดิตถ์์',
#  'อุตรดิษถ์',
#  'อุตรดิิตถ์',
#  'อุตรติดถ์',
#  'อุทัยธานี',
#  'อุทัยานี',
#  'อุบลราขธานี',
#  'อุบลราชธานี',
#  'อุบลราชธานี\xa0',
#  'อุุครดิตถ์',
#  'อุุดรธาน',
#  'อุุดรธานี',
#  'อุุตรดิตถ์',
#  'อุุทัยธานี',
#  'อุุบลราชธานี',
#  'อ่งทอง',
#  'อ่างทอง',
#  'อ่างทอง\xa0',
#  'อํานาจเจริญ',
#  'เชิงเทรา',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เชียรใหญ่',
#  'เชีียงราย',
#  'เชีียงใหม่',
#  'เด่นชัย',
#  'เพขรบุรี',
#  'เพขรบูรณื',
#  'เพขรบูรณ์',
#  'เพชรบุรณ์',
#  'เพชรบุรี',
#  'เพชรบุรึ',
#  'เพชรบุุรี',
#  'เพชรบุูรณ์',
#  'เพชรบูรณ์',
#  'เพชรบูรณ์\xa0',
#  'เพชรบูร์',
#  'เพชรบููรณ์',
#  'เมือง',
#  'เมืองตาก',
#  'เมืองน่าน',
#  'เมืองปัตตานี',
#  'เรือ',
#  'เลย',
#  'เลย\xa0',
#  'เวียงจันทร์',
#  'เวียงสา',
#  'แพร่',
#  'แม่ทะ',
#  'แม่ฮ่องสอน',
#  'แล้วป่วย',
#  'โพธิ์ทอง',
#  'ไชโย',
#  'ไม่มีข้อมูล',
#  'ไม่มีชื่อหอพัก',
#  'ไม่ระบุ'}

# %%
confirm['province_of_onset'].replace({'USA':'ไม่มีข้อมูล','\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์','\xa0กาญจนบุรี':'กาญจนบุรี','\xa0ชลบุรี':'ชลบุรี','\xa0ตราด':'ตราด','\xa0นครปฐม':'นครปฐม',
                                         '\xa0สมุทรสงคราม':'สมุทรสงคราม','\xa0สมุทรสาคร':'สมุทรสาคร','\xa0อุทัยธานี':'อุทัยธานี','กทม':'กรุงเทพมหานคร','กทม.':'กรุงเทพมหานคร','กบินทร์บุรี':'ปราจีนบุรี','กระบี่ี่':'กระบี่','กรุงเทพ':'กรุงเทพมหานคร',
                                         'กรุงเทพมหานคร.':'กรุงเทพมหานคร','กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร','กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร','กรุงเทพฯ':'กรุงเทพมหานคร','กะทู้':'ภูเก็ต',
                                         'กัมพูชา':'ไม่มีข้อมูล','กาญจบุรี':'กาญจนบุรี','กาญนบุรี':'กาญจนบุรี','กาฬสิน':'กาฬสินธุ์','กาฬสินธิ์':'กาฬสินธุ์','กาฬสินธุ์\xa0':'กาฬสินธุ์','กาฬสินธ์':'กาฬสินธุ์',
                                         'กำเพงเพชร':'กำแพงเพชร','กำแพง':'กำแพงเพชร','กำแพงเพชร':'กำแพงเพชร','กำแพงเพชร\xa0':'กำแพงเพชร','กําแพงเพชร':'กำแพงเพชร',
                                         'ขอนแก่น\xa0':'ขอนแก่น','ขอนแก่่น':'ขอนแก่น','ขานุวรลักษณ์บุรี':'กำแพงเพชร','คนไทยเดินทางกลับจากต่างประเทศ':'ไม่มีข้อมูล','คลองเตย':'กรุงเทพมหานคร','จ.กรุงเทพมหานคร':'กรุงเทพมหานคร',
                                         'จ.ภูเก็ต':'ภูเก็ต','จ.ราชบุรี':'ราชบุรี','จ.สุราษฎร์ธานี':'สุราษฎร์ธานี','จังหวัดสมุทรสาคร':'สมุทรสาคร','ฉะเชองเทราร':'ฉะเชิงเทรา','ชมพร':'ชุมพร',
                                         'ชลบุรี\t':'ชลบุรี','ชลบุรี\xa0':'ชลบุรี','ชลบุุรี':'ชลบุรี','ชอนแก่น':'ขอนแก่น','ชัยนาถ':'ชัยนาท','ชัยบาดาล':'ลพบุรี','ชัยภูมิ\xa0':'ชัยภูมิ','ชุุมพร':'ชุมพร','ชุุุมพร':'ชุมพร',
                                         'ดอนมดแดง':'อุบลราชธานี','ดินแดง':'กรุงเทพมหานคร','ตรััง':'ตรัง','ตราด\xa0':'ตราด','ตากใบ':'นราธิวาส','ต่างจังหวัด':'ไม่มีข้อมูล','ทุ่งเสลี่ยม':'สุโขทัย',
                                         'ท้ายบ้าน':'สมุทรปราการ','ธารโต':'ยะลา','นคนปฐม':'นครปฐม','นคปฐม':'นครปฐม','นครนปฐม':'นครปฐม','นครนาชสีมา':'นครราชสีมา','นครปฐม\xa0':'นครปฐม',
                                         'นครปบม':'นครปฐม','นครพนม\xa0':'นครพนม','นครยายก':'นครนายก','นครราขสีมา':'นครราชสีมา','นครราชธานี':'นครราชสีมา','นครราชศรีมา':'นครราชสีมา','นครราชสสีมา':'นครราชสีมา',
                                         'นครราชสีมา ลพบุรี':'นครราชสีมา','นครราชสีมา\xa0':'นครราชสีมา','นครศรธรรมราช':'นครศรีธรรมราช','นครศรี':'นครศรีธรรมราช','นครศรีธรมมราช':'นครศรีธรรมราช',
                                         'นครศรีธรมราช':'นครศรีธรรมราช','นครศรีธรรมราข':'นครศรีธรรมราช','นครศรีฯ':'นครศรีธรรมราช','นครศรีีธรรมราช':'นครศรีธรรมราช','นครศร๊ธรรมราช':'นครศรีธรรมราช',
                                         'นครศร๊ะรรมราช':'นครศรีธรรมราช','นครสรรค์':'นครสวรรค์','นครสรีธรรมราช':'นครศรีธรรมราช','นครสวรรค':'นครสวรรค์','นครสวรรค์\xa0':'นครสวรรค์','นครสีธรรมราช':'นครศรีธรรมราช',
                                         'นครฯ':'นครศรีธรรมราช','นคราชสีมา':'นครราชสีมา','นครีศรีธรรมราช':'นครศรีธรรมราช','นตรนายก':'นครนายก','นตรปฐม':'นครปฐม','นนทบุรี\xa0':'นนทบุรี',
                                         'นนทบุุรี':'นนทบุรี','นนทุบรี':'นนทบุรี','นนทุรี':'นนทบุรี','นนมบุรี':'นนทบุรี','นรศรีธรรมราช':'นครศรีธรรมราช','นราธิวาส\u200b':'นราธิวาส','นราธฺวาส':'นราธิวาส','นอกเขต':'ไม่มีข้อมูล',
                                         'นาราธิวาส':'นราธิวาส','นาวัง':'หนองบัวลำภู','น่าน/ฉะเชิงเทรา':'น่าน','บางกรวย':'นนทบุรี','บางกะปิ':'กรุงเทพมหานคร','บางนา':'กรุงเทพมหานคร','บางปะอิน':'กรุงเทพมหานคร',
                                         'บางละมุง':'ชลบุรี','บางศรีเมือง':'นนทบุรี','บางเพียง':'สมุทรปราการ','บึงโขงหลง':'บึงกาฬ','บุรีรัมภ์':'บุรีรัมย์','บุรีรัมย์\xa0':'บุรีรัมย์','บุรีรัยม์':'บุรีรัมย์','บุรีรีมย์':'บุรีรัมย์',
                                         'บ้านหลวง':'น่าน','ปจ':'ไม่มีข้อมูล','ปทึมธานี':'ปทุมธานี','ปทุทธานี':'ปทุมธานี','ปทุมฑานี':'ปทุมธานี','ปทุมทานี':'ปทุมธานี','ปทุมธาน':'ปทุมธานี','ปทุมธานี\xa0':'ปทุมธานี','ปทุมาธานี':'ปทุมธานี',
                                         'ปธุมธานี':'ปทุมธานี','ปทุมธานี.':'ปทุมธานี','ปทุมธานีี':'ปทุมธานี','ปทุุมธานี':'ปทุมธานี','ปมุมธานี':'ปทุมธานี',
                                         'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์','ประจวบ':'ประจวบคีรีขันธ์','ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีรีขัน':'ประจวบคีรีขันธ์',
                                         'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์','ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์','ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์',
                                         'ประจวบฯ':'ประจวบคีรีขันธ์','ประทุมธานี':'ปทุมธานี', 'ประเทศกัมพูชา':'ไม่มีข้อมูล','ปราจีบุรี':'ปราจีนบุรี','ปลวกแดง':'ระยอง','ปลายพระยา':'กระบี่', 'ปอยเปต':'ไม่มีข้อมูล','ปัตตนรี':'ปัตตานี',
                                         'ปัตตานนี':'ปัตตานี','ปัตตานีี':'ปัตตานี','ปัว':'น่าน','ปััตตานี':'ปัตตานี','ปุทมธานี':'ปทุมธานี','ป่าโมก':'อ่างทอง','พม่า':'ไม่มีข้อมูล','พรหมพิราม':'พิษณุโลก','พระนครศรียุธยา':'พระนครศรีอยุธยา',
                                         'พระนครศรีอยุทธยา':'พระนครศรีอยุธยา','พระนครศรีอยุทยา':'พระนครศรีอยุธยา','พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา','พัทยา':'ชลบุรี','พัทลุุง':'พัทลุง','พัังงา':'พังงา',
                                         'พิษณุโลก\xa0':'พิษณุโลก','พิษณูโลก':'พิษณุโลก','ฟินแลนด์':'ไม่มีข้อมูล','ภาษีเจริญ':'กรุงเทพมหานคร','ภุเก็ต':'ภูเก็ต','ภูุเก็ต':'ภูเก็ต','ภููเก็ต':'ภูเก็ต','ภูเก็็ต':'ภูเก็ต','ภูเพียง':'น่าน',
                                         'มหาสาคาม':'มหาสารคาม','มาเลเซีย':'ไม่มีข้อมูล','มุกาดหาร':'มุกดาหาร','ยานนาวา':'กรุงเทพมหานคร','ร.จ.จ.นราธิวาส':'นราธิวาส','รอ':'ร้อยเอ็ด','ระบุ':'ไม่มีข้อมูล','ระยอง\xa0':'ระยอง',
                                         'ระอยง':'ระยอง','ราชบบุรี':'ราชบุรี','ราชบุรีี':'ราชบุรี','ราชบุรี\u200b':'ราชบุรี','ราชุรี':'ราชบุรี','ราชเทวี':'กรุงเทพมหานคร','ร้องกวาง':'แพร่','ลบุรี':'ลพบุรี','ลพบุรี.':'ลพบุรี','ลพบุรี\xa0':'ลพบุรี','ลอง':'แพร่',
                                         'ลาดกระบัง':'กรุงเทพมหานคร','ลาดพร้าว':'กรุงเทพมหานคร','ลาว':'ไม่มีข้อมูล','ลำพูน\u200b':'ลำพูน','ลำพููน':'ลำพูน','ลำลูกกา':'ปทุมธานี','วังชิ้น':'ลำปาง','วังทอง':'พิษณุโลก',
                                         'วิเศษชัยชาญ':'อ่างทอง','ศรีษะสะเกษ':'ศรีสะเกษ','ศรีษะเกษ':'ศรีสะเกษ','ศรีสระเกษ':'ศรีสะเกษ','ศีรสะเกษ':'ศรีสะเกษ','สครสวรรค์':'นครสวรรค์',
                                         'สงขลา\u200b':'สงขลา','สถานที่ทำงาน':'ไม่มีข้อมูล','สพรรณบุรี':'สุพรรณบุรี','สมถทรปราการ':'สมุทรปราการ','สมทรสงคราม':'สมุทรสงคราม','สมทรสาคร':'สมุทรสาคร','สมุครปราการ':'สมุทรปราการ',
                                         'สมุครสาคร':'สมุทรสาคร','สมุท':'ไม่มีข้อมูล','สมุทปราการ':'สมุทรปราการ','สมุทรปรากร':'สมุทรปราการ','สมุทรปรากรร':'สมุทรปราการ','สมุทรปราการ\xa0':'สมุทรปราการ','สมุทรศาคร':'สมุทรสาคร',
                                         'สมุทรสาคร\xa0':'สมุทรสาคร','สมุทรสาคา':'สมุทรสาคร','สมุทรสาคาร':'สมุทรสาคร','สมุทรสาทร':'สมุทรสาคร','สมุทรสารคร':'สมุทรสาคร','สมุทราปราการ':'สมุทรปราการ',
                                         'สมุทราสาคร':'สมุทรสาคร','สมุทสงคราม':'สมุทรสงคราม','สมุทสาคร':'สมุทรสาคร','สมุย':'สุราษฎร์ธานี','สมุุทรปราการ':'สมุทรปราการ','สมุุทรสงคราม':'สมุทรสงคราม','สมุุทรสาคร':'สมุทรสาคร',
                                         'สระก้ว':'สระแก้ว','สระบุรี\xa0':'สระบุรี','สรินทร์':'สุรินทร์','สวิสเซอร์แลนด์':'ไม่มีข้อมูล','สอง':'แพร่','สองแคว':'น่าน','สะพานสูง':'กรุงเทพมหานคร',
                                         'สะแก้ว':'สระแก้ว','สัตหีบ':'ชลบุรี','สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่มีข้อมูล','สามุทรสาคร':'สมุทรสาคร','สารคาม':'มหาสารคาม','สารภี':'เชียงใหม่','สิงห์บุรี\xa0':'สิงห์บุรี',
                                         'สุทรปราการ':'สมุทรปราการ','สุพรรญบุรี':'สุพรรณบุรี','สุพรรณบุรั':'สุพรรณบุรี','สุพรรณบุรี\xa0':'สุพรรณบุรี','สุมทรปราการ':'สมุทรปราการ',
                                         'สุมทรสาคร':'สมุทรสาคร','สุมุทรปราการ':'สมุทรปราการ','สุมุทรสาคร':'สมุทรสาคร','สุระบุรี':'สระบุรี','สุราษ':'สุราษฎร์ธานี','สุราษฎณ์ธานี':'สุราษฎร์ธานี','สุราษฎธานี':'สุราษฎร์ธานี',
                                         'สุราษฎร์':'สุราษฎร์ธานี','สุราษฎร์ฯ':'สุราษฎร์ธานี','สุราษฎร์์ธานี':'สุราษฎร์ธานี','สุราษฎ์ธานี':'สุราษฎร์ธานี','สุราษฏร์ธานี':'สุราษฎร์ธานี','สุราษธานี':'สุราษฎร์ธานี',
                                         'สุราษร์ฎธานี':'สุราษฎร์ธานี','สุราษร์ธานี':'สุราษฎร์ธานี','สุราษฯ':'สุราษฎร์ธานี','สุรินทรื':'สุรินทร์','สุรินทร์ 32150':'สุรินทร์','สุรินทร์,รีสะเกษ':'สุรินทร์','สุรินทร์\xa0':'สุรินทร์','สุริมทร์':'สุรินทร์',
                                         'สุริะแก้ว':'สระแก้ว','สุวรรณภูมิ':'สมุทรปราการ','สุุพรรณบุรี':'สุพรรณบุรี','สุุราษฎร์ธานี':'สุราษฎร์ธานี','สุุราษฏร์ธานี':'สุราษฎร์ธนี','สุุราษฯ':'สุราษฎร์ธนี','สุุรินทร์':'สุรินทร์',
                                         'สุุุโขทัย':'สุโขทัย','สุโขทับ':'สุโขทัย','สุโขทัย\xa0':'สุโขทัย','สูงเม่น':'แพร่','หนวงบัวลำภู':'หนองบัวลำภู','หนองงคาย':'หนองคาย','หนองบัวภู':'หนองบัวลำภู',
                                         'หนองบัวลำพูน':'หนองบัวลำภู','หนองบัวลําภู':'หนองบัวลำภู','หนองบััวลำภู':'หนองบัวลำภู','หนองม่วงไข่':'แพร่','หนอบัวลำภู':'หนองบัวลำภู','หลายจังหวัด':'ไม่มีข้อมูล','หัวหิน':'ประจวบคีรีขันธ์',
                                         'ห้วยขวาง':'กรุงเทพมหานคร','อยุทธยา':'พระนครศรีอยุธยา','อยุธยา':'พระนครศรีอยุธยา','อยุุธยา':'พระนครศรีอยุธยา','อำนาจเจิญ':'อำนาจเจริญ','อำนาญเจริญ':'อำนาจเจริญ','อำนาเจริญ':'อำนาจเจริญ',
                                         'อิสราเอล':'ไม่มีข้อมูล','อุดธานี':'อุดรธานี','อุดร':'อุดรธานี','อุดรธาณี':'อุดรธานี','อุดรธานี\xa0':'อุดรธานี','อุดรธานีี':'อุดรธานี','อุดรราชธานี':'อุดรธานี','อุตรดิตถ์\xa0':'อุตรดิตถ์',
                                         'อุตรดิตถ์์':'อุตรดิตถ์','อุตรดิษถ์':'อุตรดิตถ์','อุตรดิิตถ์':'อุตรดิตถ์','อุตรติดถ์':'อุตรดิตถ์','อุบลราขธานี':'อุบลราชธานี','อุบลราชธานี\xa0':'อุบลราชธานี','อุุครดิตถ์':'อุตรดิตถ์',
                                         'อุุดรธาน':'อุดรธานี','อุุดรธานี':'อุดรธานี','อุุตรดิตถ์':'อุตรดิตถ์','อุุทัยธานี':'อุทัยธานี','อุุบลราชธานี':'อุบลราชธานี','อ่งทอง':'อ่างทอง','อ่างทอง\xa0':'อ่างทอง','อํานาจเจริญ':'อำนาจเจริญ',
                                         'เชิงเทรา':'ฉะเชิงเทรา','เชียรใหญ่':'นครศรีธรรมราช','เชีียงราย':'เชียงราย','เชีียงใหม่':'เชียงใหม่','เด่นชัย':'แพร่','ขัยนาท':'ชัยนาท','อุทัยานี':'อุทัยธานี',
                                         'เพขรบุรี':'เพชรบูรณ์','เพขรบูรณื':'เพชรบูรณ์','เพขรบูรณ์':'เพชรบูรณ์','เพชรบุรณ์':'เพชรบูรณ์','เพชรบุรี':'เพชรบูรณ์','เพชรบุรึ':'เพชรบูรณ์','เพชรบุุรี':'เพชรบูรณ์','เพชรบุูรณ์':'เพชรบูรณ์','เพชรบูรณ์\xa0':'เพชรบูรณ์',
                                         'เพชรบูร์':'เพชรบูรณ์','เพชรบููรณ์':'เพชรบูรณ์','เมือง':'แพร่','เมืองตาก':'ตาก','เมืองน่าน':'น่าน','เมืองปัตตานี':'ปัตตานี','เรือ':'เลย','เลย\xa0':'เลย','เวียงจันทร์':'ไม่มีข้อมูล','เวียงสา':'น่าน','แม่ทะ':'ลำปาง',
                                         'แล้วป่วย':'ไม่มีข้อมูล','โพธิ์ทอง':'อ่างทอง','ไชโย':'อ่างทอง','ไม่มีข้อมูล':'ไม่มีข้อมูล','ไม่มีชื่อหอพัก':'ไม่มีข้อมูล','ไม่ระบุ':'ไม่มีข้อมูล','สมุทรปรากา':'สมุทรปราการ','สุราษฎร์ธนี':'สุราษฎร์ธานี','สุราษฎร์ธนี':'สุราษฎร์ธานี','ขัยภูมิ':'ชัยภูมิ'}, inplace=True)# แก้ไขข้อมูลที่พิมพ์จังหวัดผิด ให้อยู่ในชื่อจังหวัดที่ถูกต้อง

# %%
set(confirm['province_of_onset'])
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธนี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราชธานี',
#  'อ่างทอง',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เพชรบูรณ์',
#  'เลย',
#  'แพร่',
#  'แม่ฮ่องสอน',
#  'ไม่มีข้อมูล'}

# %% [markdown]
# ###ข้อมูลภูมิภาค

# %%
data_province = {'จังหวัด': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            '6 ภูมิภาค (ภูมิศาสตร์)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']}

# %%
data6 = pd.DataFrame.from_dict(data_province)
data6
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ###รวมตารางของภูมิภาคกับโควิด

# %%
case_pro=  confirm.merge(data6,how='right',left_on='province_of_onset',right_on = 'จังหวัด')
case_pro
# Out:
#                No. announce_date Notified date          sex        age  \
# 0            973.0     26/3/2020     25/3/2020          ชาย       48.0
# 1           1864.0      2/4/2020      1/4/2020         หญิง       46.0
# 2           6493.0    30/12/2020    29/12/2020         หญิง       37.0
# 3           7390.0      3/1/2021      2/1/2021         หญิง       26.0
# 4          31038.0     10/4/2021      9/4/2021          ชาย       38.0
# ...            ...           ...           ...          ...        ...
# 2904754  3271105.0     17/3/2022     16/3/2022         หญิง        5.0
# 2904755  3272635.0     17/3/2022     16/3/2022  ไม่มีข้อมูล       37.0
# 2904756  3293983.0     18/3/2022     17/3/2022          ชาย       54.0
# 2904757  3297287.0     18/3/2022     17/3/2022         หญิง       40.0
# 2904758  3300240.0     18/3/2022     17/3/2022  ไม่มีข้อมูล  37.136383
#
#                 Unit  nationality province_of_isolation  \
# 0                 ปี     Thailand            อำนาจเจริญ
# 1                 ปี     Thailand            อำนาจเจริญ
# 2                 ปี     Thailand            อำนาจเจริญ
# 3                 ปี         Laos            อำนาจเจริญ
# 4                 ปี     Thailand            อำนาจเจริญ
# ...              ...          ...                   ...
# 2904754           ปี     Thailand                  ตรัง
# 2904755           ปี  ไม่มีข้อมูล         กรุงเทพมหานคร
# 2904756           ปี     Thailand                 ยโสธร
# 2904757           ปี     Thailand                ภูเก็ต
# 2904758  ไม่มีข้อมูล  ไม่มีข้อมูล         กรุงเทพมหานคร
#
#                                                   risk province_of_onset  \
# 0                                          สถานบันเทิง        อำนาจเจริญ
# 1                        คนไทยเดินทางกลับจากต่างประเทศ        อำนาจเจริญ
# 2                                        Cluster ระยอง        อำนาจเจริญ
# 3          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# 4        ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว        อำนาจเจริญ
# ...                                                ...               ...
# 2904754                                          อื่นๆ              ตรัง
# 2904755                                          อื่นๆ              ตรัง
# 2904756                                          อื่นๆ              ตรัง
# 2904757                                          อื่นๆ              ตรัง
# 2904758                                          อื่นๆ              ตรัง
#
#         district_of_onset Unnamed: 11     จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0                   เมือง         NaN  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1             ปทุมราชวงศา         NaN  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 2                หัวตะพาน         NaN  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 3                หัวตะพาน         NaN  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 4                   เมือง         NaN  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# ...                   ...         ...         ...                    ...
# 2904754         ย่านตาขาว         NaN        ตรัง                    ใต้
# 2904755         ย่านตาขาว         NaN        ตรัง                    ใต้
# 2904756       ไม่มีข้อมูล         NaN        ตรัง                    ใต้
# 2904757             สิเกา         NaN        ตรัง                    ใต้
# 2904758            กันตัง         NaN        ตรัง                    ใต้
#
# [2904759 rows x 14 columns]

# %%
case_pro0 = case_pro.drop(['Unnamed: 11'], axis = 1)
case_pro0
# Out:
#                No. announce_date Notified date          sex        age  \
# 0            973.0     26/3/2020     25/3/2020          ชาย       48.0
# 1           1864.0      2/4/2020      1/4/2020         หญิง       46.0
# 2           6493.0    30/12/2020    29/12/2020         หญิง       37.0
# 3           7390.0      3/1/2021      2/1/2021         หญิง       26.0
# 4          31038.0     10/4/2021      9/4/2021          ชาย       38.0
# ...            ...           ...           ...          ...        ...
# 2904754  3271105.0     17/3/2022     16/3/2022         หญิง        5.0
# 2904755  3272635.0     17/3/2022     16/3/2022  ไม่มีข้อมูล       37.0
# 2904756  3293983.0     18/3/2022     17/3/2022          ชาย       54.0
# 2904757  3297287.0     18/3/2022     17/3/2022         หญิง       40.0
# 2904758  3300240.0     18/3/2022     17/3/2022  ไม่มีข้อมูล  37.136383
#
#                 Unit  nationality province_of_isolation  \
# 0                 ปี     Thailand            อำนาจเจริญ
# 1                 ปี     Thailand            อำนาจเจริญ
# 2                 ปี     Thailand            อำนาจเจริญ
# 3                 ปี         Laos            อำนาจเจริญ
# 4                 ปี     Thailand            อำนาจเจริญ
# ...              ...          ...                   ...
# 2904754           ปี     Thailand                  ตรัง
# 2904755           ปี  ไม่มีข้อมูล         กรุงเทพมหานคร
# 2904756           ปี     Thailand                 ยโสธร
# 2904757           ปี     Thailand                ภูเก็ต
# 2904758  ไม่มีข้อมูล  ไม่มีข้อมูล         กรุงเทพมหานคร
#
#                                                   risk province_of_onset  \
# 0                                          สถานบันเทิง        อำนาจเจริญ
# 1                        คนไทยเดินทางกลับจากต่างประเทศ        อำนาจเจริญ
# 2                                        Cluster ระยอง        อำนาจเจริญ
# 3          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# 4        ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว        อำนาจเจริญ
# ...                                                ...               ...
# 2904754                                          อื่นๆ              ตรัง
# 2904755                                          อื่นๆ              ตรัง
# 2904756                                          อื่นๆ              ตรัง
# 2904757                                          อื่นๆ              ตรัง
# 2904758                                          อื่นๆ              ตรัง
#
#         district_of_onset     จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0                   เมือง  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1             ปทุมราชวงศา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 2                หัวตะพาน  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 3                หัวตะพาน  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 4                   เมือง  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# ...                   ...         ...                    ...
# 2904754         ย่านตาขาว        ตรัง                    ใต้
# 2904755         ย่านตาขาว        ตรัง                    ใต้
# 2904756       ไม่มีข้อมูล        ตรัง                    ใต้
# 2904757             สิเกา        ตรัง                    ใต้
# 2904758            กันตัง        ตรัง                    ใต้
#
# [2904759 rows x 13 columns]

# %%
case_pro0.isnull().any()
# Out:
# No.                        True
# announce_date              True
# Notified date              True
# sex                        True
# age                        True
# Unit                       True
# nationality                True
# province_of_isolation      True
# risk                       True
# province_of_onset          True
# district_of_onset          True
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# dtype: bool

# %%
case_pro1=case_pro0.dropna()
case_pro1
# Out:
#                No. announce_date Notified date          sex        age  \
# 0            973.0     26/3/2020     25/3/2020          ชาย       48.0
# 1           1864.0      2/4/2020      1/4/2020         หญิง       46.0
# 2           6493.0    30/12/2020    29/12/2020         หญิง       37.0
# 3           7390.0      3/1/2021      2/1/2021         หญิง       26.0
# 4          31038.0     10/4/2021      9/4/2021          ชาย       38.0
# ...            ...           ...           ...          ...        ...
# 2904754  3271105.0     17/3/2022     16/3/2022         หญิง        5.0
# 2904755  3272635.0     17/3/2022     16/3/2022  ไม่มีข้อมูล       37.0
# 2904756  3293983.0     18/3/2022     17/3/2022          ชาย       54.0
# 2904757  3297287.0     18/3/2022     17/3/2022         หญิง       40.0
# 2904758  3300240.0     18/3/2022     17/3/2022  ไม่มีข้อมูล  37.136383
#
#                 Unit  nationality province_of_isolation  \
# 0                 ปี     Thailand            อำนาจเจริญ
# 1                 ปี     Thailand            อำนาจเจริญ
# 2                 ปี     Thailand            อำนาจเจริญ
# 3                 ปี         Laos            อำนาจเจริญ
# 4                 ปี     Thailand            อำนาจเจริญ
# ...              ...          ...                   ...
# 2904754           ปี     Thailand                  ตรัง
# 2904755           ปี  ไม่มีข้อมูล         กรุงเทพมหานคร
# 2904756           ปี     Thailand                 ยโสธร
# 2904757           ปี     Thailand                ภูเก็ต
# 2904758  ไม่มีข้อมูล  ไม่มีข้อมูล         กรุงเทพมหานคร
#
#                                                   risk province_of_onset  \
# 0                                          สถานบันเทิง        อำนาจเจริญ
# 1                        คนไทยเดินทางกลับจากต่างประเทศ        อำนาจเจริญ
# 2                                        Cluster ระยอง        อำนาจเจริญ
# 3          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# 4        ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว        อำนาจเจริญ
# ...                                                ...               ...
# 2904754                                          อื่นๆ              ตรัง
# 2904755                                          อื่นๆ              ตรัง
# 2904756                                          อื่นๆ              ตรัง
# 2904757                                          อื่นๆ              ตรัง
# 2904758                                          อื่นๆ              ตรัง
#
#         district_of_onset     จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0                   เมือง  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1             ปทุมราชวงศา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 2                หัวตะพาน  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 3                หัวตะพาน  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 4                   เมือง  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# ...                   ...         ...                    ...
# 2904754         ย่านตาขาว        ตรัง                    ใต้
# 2904755         ย่านตาขาว        ตรัง                    ใต้
# 2904756       ไม่มีข้อมูล        ตรัง                    ใต้
# 2904757             สิเกา        ตรัง                    ใต้
# 2904758            กันตัง        ตรัง                    ใต้
#
# [2904758 rows x 13 columns]

# %%
case_pro1.isnull().any()
# Out:
# No.                       False
# announce_date             False
# Notified date             False
# sex                       False
# age                       False
# Unit                      False
# nationality               False
# province_of_isolation     False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# dtype: bool

# %%
smaller_table = case_pro1[['No.','announce_date','sex','province_of_onset','risk','6 ภูมิภาค (ภูมิศาสตร์)']]  #เลือกมาเฉพาะชื่อคอลัมน์ที่ต้องการ  เป็น list ลำดับมีความสำคัญ
smaller_table
# Out:
#                No. announce_date          sex province_of_onset  \
# 0            973.0     26/3/2020          ชาย        อำนาจเจริญ
# 1           1864.0      2/4/2020         หญิง        อำนาจเจริญ
# 2           6493.0    30/12/2020         หญิง        อำนาจเจริญ
# 3           7390.0      3/1/2021         หญิง        อำนาจเจริญ
# 4          31038.0     10/4/2021          ชาย        อำนาจเจริญ
# ...            ...           ...          ...               ...
# 2904754  3271105.0     17/3/2022         หญิง              ตรัง
# 2904755  3272635.0     17/3/2022  ไม่มีข้อมูล              ตรัง
# 2904756  3293983.0     18/3/2022          ชาย              ตรัง
# 2904757  3297287.0     18/3/2022         หญิง              ตรัง
# 2904758  3300240.0     18/3/2022  ไม่มีข้อมูล              ตรัง
#
#                                                   risk 6 ภูมิภาค (ภูมิศาสตร์)
# 0                                          สถานบันเทิง     ตะวันออกเฉียงเหนือ
# 1                        คนไทยเดินทางกลับจากต่างประเทศ     ตะวันออกเฉียงเหนือ
# 2                                        Cluster ระยอง     ตะวันออกเฉียงเหนือ
# 3          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     ตะวันออกเฉียงเหนือ
# 4        ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     ตะวันออกเฉียงเหนือ
# ...                                                ...                    ...
# 2904754                                          อื่นๆ                    ใต้
# 2904755                                          อื่นๆ                    ใต้
# 2904756                                          อื่นๆ                    ใต้
# 2904757                                          อื่นๆ                    ใต้
# 2904758                                          อื่นๆ                    ใต้
#
# [2904758 rows x 6 columns]

# %%
smaller_table.isnull().any()
# Out:
# No.                       False
# announce_date             False
# sex                       False
# province_of_onset         False
# risk                      False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# dtype: bool

# %%
set(smaller_table['sex'])
# Out:
# {'ช', 'ชาย', 'ญ', 'นาย', 'ร.ต.ท.', 'หญิง', 'หณิง', 'หห', 'ไม่มีข้อมูล'}

# %%
smaller_table['sex'].replace({'ช':'ชาย','ญ':'หญิง','นาย':'ชาย','ร.ต.ท.':'ไม่มีข้อมูล','หณิง':'หญิง','หห':'หญิง',
                                         }, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
set(smaller_table['sex'])
# Out:
# {'ชาย', 'หญิง', 'ไม่มีข้อมูล'}

# %%
data_Labour1 = pd.read_csv(os.path.join(path,'sector_02_28_TH_.csv'))
data_Labour1
# Out:
#             จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 0     กรุงเทพมหานคร           95233           86233           91392
# 1       สมุทรปราการ           25526           15271           16160
# 2           นนทบุรี           22258            8888            8822
# 3          ปทุมธานี            5377            7117            6056
# 4   พระนครศรีอยุธยา           13023           10947           11551
# ..              ...             ...             ...             ...
# 72             ตรัง            1487            1204            1367
# 73           พัทลุง            1809            1977            1850
# 74          ปัตตานี            3345            3542            5068
# 75             ยะลา            3235            3582            4255
# 76         นราธิวาส            2253            2671            2509
#
#     จำนวนคนปี 2563  จำนวนคนปี 2564
# 0           221048           97607
# 1            24841           14489
# 2            15768           10070
# 3             7496           19589
# 4            11399           10726
# ..             ...             ...
# 72            2621            2276
# 73            2217            2792
# 74            5964            3523
# 75            3929            5765
# 76            2804            3289
#
# [77 rows x 6 columns]

# %%
data_Labour1.isnull().any()
# Out:
# จังหวัด           False
# จำนวนคนปี 2560    False
# จำนวนคนปี 2561    False
# จำนวนคนปี 2662    False
# จำนวนคนปี 2563    False
# จำนวนคนปี 2564    False
# dtype: bool

# %%
covid1 = smaller_table.merge(data_Labour1,how='right',left_on='province_of_onset',right_on = 'จังหวัด')
covid1
# Out:
#                No. announce_date          sex province_of_onset  \
# 0              1.0     12/1/2020         หญิง     กรุงเทพมหานคร
# 1              2.0     17/1/2020         หญิง     กรุงเทพมหานคร
# 2              4.0     22/1/2020          ชาย     กรุงเทพมหานคร
# 3              5.0     24/1/2020         หญิง     กรุงเทพมหานคร
# 4              6.0     25/1/2020         หญิง     กรุงเทพมหานคร
# ...            ...           ...          ...               ...
# 2904754  3297872.0     18/3/2022          ชาย          นราธิวาส
# 2904755  3298018.0     18/3/2022          ชาย          นราธิวาส
# 2904756  3298348.0     18/3/2022          ชาย          นราธิวาส
# 2904757  3300146.0     18/3/2022  ไม่มีข้อมูล          นราธิวาส
# 2904758  3300379.0     18/3/2022  ไม่มีข้อมูล          นราธิวาส
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                              ...                    ...
# 2904754                                        อื่นๆ                    ใต้
# 2904755  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2904756                         อยู่ระหว่างการสอบสวน                    ใต้
# 2904757                                        อื่นๆ                    ใต้
# 2904758                                        อื่นๆ                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 0        กรุงเทพมหานคร           95233           86233           91392
# 1        กรุงเทพมหานคร           95233           86233           91392
# 2        กรุงเทพมหานคร           95233           86233           91392
# 3        กรุงเทพมหานคร           95233           86233           91392
# 4        กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2904754       นราธิวาส            2253            2671            2509
# 2904755       นราธิวาส            2253            2671            2509
# 2904756       นราธิวาส            2253            2671            2509
# 2904757       นราธิวาส            2253            2671            2509
# 2904758       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 0                221048           97607
# 1                221048           97607
# 2                221048           97607
# 3                221048           97607
# 4                221048           97607
# ...                 ...             ...
# 2904754            2804            3289
# 2904755            2804            3289
# 2904756            2804            3289
# 2904757            2804            3289
# 2904758            2804            3289
#
# [2904759 rows x 12 columns]

# %%
covid2= covid1.dropna()
covid2
# Out:
#                No. announce_date          sex province_of_onset  \
# 0              1.0     12/1/2020         หญิง     กรุงเทพมหานคร
# 1              2.0     17/1/2020         หญิง     กรุงเทพมหานคร
# 2              4.0     22/1/2020          ชาย     กรุงเทพมหานคร
# 3              5.0     24/1/2020         หญิง     กรุงเทพมหานคร
# 4              6.0     25/1/2020         หญิง     กรุงเทพมหานคร
# ...            ...           ...          ...               ...
# 2904754  3297872.0     18/3/2022          ชาย          นราธิวาส
# 2904755  3298018.0     18/3/2022          ชาย          นราธิวาส
# 2904756  3298348.0     18/3/2022          ชาย          นราธิวาส
# 2904757  3300146.0     18/3/2022  ไม่มีข้อมูล          นราธิวาส
# 2904758  3300379.0     18/3/2022  ไม่มีข้อมูล          นราธิวาส
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                              ...                    ...
# 2904754                                        อื่นๆ                    ใต้
# 2904755  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2904756                         อยู่ระหว่างการสอบสวน                    ใต้
# 2904757                                        อื่นๆ                    ใต้
# 2904758                                        อื่นๆ                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 0        กรุงเทพมหานคร           95233           86233           91392
# 1        กรุงเทพมหานคร           95233           86233           91392
# 2        กรุงเทพมหานคร           95233           86233           91392
# 3        กรุงเทพมหานคร           95233           86233           91392
# 4        กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2904754       นราธิวาส            2253            2671            2509
# 2904755       นราธิวาส            2253            2671            2509
# 2904756       นราธิวาส            2253            2671            2509
# 2904757       นราธิวาส            2253            2671            2509
# 2904758       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 0                221048           97607
# 1                221048           97607
# 2                221048           97607
# 3                221048           97607
# 4                221048           97607
# ...                 ...             ...
# 2904754            2804            3289
# 2904755            2804            3289
# 2904756            2804            3289
# 2904757            2804            3289
# 2904758            2804            3289
#
# [2904758 rows x 12 columns]

# %%
covid2['announce_date'] = pd.to_datetime(covid2['announce_date'],format="%d/%m/%Y")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
covid2
# Out:
#                No. announce_date          sex province_of_onset  \
# 0              1.0    2020-01-12         หญิง     กรุงเทพมหานคร
# 1              2.0    2020-01-17         หญิง     กรุงเทพมหานคร
# 2              4.0    2020-01-22          ชาย     กรุงเทพมหานคร
# 3              5.0    2020-01-24         หญิง     กรุงเทพมหานคร
# 4              6.0    2020-01-25         หญิง     กรุงเทพมหานคร
# ...            ...           ...          ...               ...
# 2904754  3297872.0    2022-03-18          ชาย          นราธิวาส
# 2904755  3298018.0    2022-03-18          ชาย          นราธิวาส
# 2904756  3298348.0    2022-03-18          ชาย          นราธิวาส
# 2904757  3300146.0    2022-03-18  ไม่มีข้อมูล          นราธิวาส
# 2904758  3300379.0    2022-03-18  ไม่มีข้อมูล          นราธิวาส
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                              ...                    ...
# 2904754                                        อื่นๆ                    ใต้
# 2904755  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2904756                         อยู่ระหว่างการสอบสวน                    ใต้
# 2904757                                        อื่นๆ                    ใต้
# 2904758                                        อื่นๆ                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 0        กรุงเทพมหานคร           95233           86233           91392
# 1        กรุงเทพมหานคร           95233           86233           91392
# 2        กรุงเทพมหานคร           95233           86233           91392
# 3        กรุงเทพมหานคร           95233           86233           91392
# 4        กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2904754       นราธิวาส            2253            2671            2509
# 2904755       นราธิวาส            2253            2671            2509
# 2904756       นราธิวาส            2253            2671            2509
# 2904757       นราธิวาส            2253            2671            2509
# 2904758       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 0                221048           97607
# 1                221048           97607
# 2                221048           97607
# 3                221048           97607
# 4                221048           97607
# ...                 ...             ...
# 2904754            2804            3289
# 2904755            2804            3289
# 2904756            2804            3289
# 2904757            2804            3289
# 2904758            2804            3289
#
# [2904758 rows x 12 columns]

# %%
data_covid = covid2.groupby('province_of_onset')[['No.']].count() #จัดกลุ่มตามจังหวัดและนับจำนวนคนในแต่ละจังหวัด
data_covid
# Out:
#                       No.
# province_of_onset
# กระบี่              17641
# กรุงเทพมหานคร      567217
# กาญจนบุรี           24322
# กาฬสินธุ์           18589
# กำแพงเพชร           13042
# ...                   ...
# เชียงใหม่           42422
# เพชรบูรณ์           48551
# เลย                  9927
# แพร่                 5700
# แม่ฮ่องสอน           4145
#
# [76 rows x 1 columns]

# %%
covid_1 = covid2[covid2['announce_date'] <= '2020-12-31']  
covid_1
# Out:
#             No. announce_date   sex province_of_onset  \
# 0           1.0    2020-01-12  หญิง     กรุงเทพมหานคร
# 1           2.0    2020-01-17  หญิง     กรุงเทพมหานคร
# 2           4.0    2020-01-22   ชาย     กรุงเทพมหานคร
# 3           5.0    2020-01-24  หญิง     กรุงเทพมหานคร
# 4           6.0    2020-01-25  หญิง     กรุงเทพมหานคร
# ...         ...           ...   ...               ...
# 2858154  3034.0    2020-05-19  หญิง          นราธิวาส
# 2858155  3052.0    2020-05-27   ชาย          นราธิวาส
# 2858156  3078.0    2020-05-30   ชาย          นราธิวาส
# 2858157  3082.0    2020-05-31   ชาย          นราธิวาส
# 2858158  6023.0    2020-12-27  หญิง          นราธิวาส
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                              ...                    ...
# 2858154  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2858155                             State Quarantine                    ใต้
# 2858156                             State Quarantine                    ใต้
# 2858157                             State Quarantine                    ใต้
# 2858158                            Cluster สมุทรสาคร                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 0        กรุงเทพมหานคร           95233           86233           91392
# 1        กรุงเทพมหานคร           95233           86233           91392
# 2        กรุงเทพมหานคร           95233           86233           91392
# 3        กรุงเทพมหานคร           95233           86233           91392
# 4        กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2858154       นราธิวาส            2253            2671            2509
# 2858155       นราธิวาส            2253            2671            2509
# 2858156       นราธิวาส            2253            2671            2509
# 2858157       นราธิวาส            2253            2671            2509
# 2858158       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 0                221048           97607
# 1                221048           97607
# 2                221048           97607
# 3                221048           97607
# 4                221048           97607
# ...                 ...             ...
# 2858154            2804            3289
# 2858155            2804            3289
# 2858156            2804            3289
# 2858157            2804            3289
# 2858158            2804            3289
#
# [6521 rows x 12 columns]

# %%
covid_2 = covid2[(covid2['announce_date'] >='2021-01-01') & (covid2['announce_date'] <='2021-03-31')] 
covid_2
# Out:
#              No. announce_date   sex province_of_onset  \
# 2214      6890.0    2021-01-01  หญิง     กรุงเทพมหานคร
# 2215      6891.0    2021-01-01   ชาย     กรุงเทพมหานคร
# 2216      6895.0    2021-01-01   ชาย     กรุงเทพมหานคร
# 2217      6896.0    2021-01-01   ชาย     กรุงเทพมหานคร
# 2218      6897.0    2021-01-01   ชาย     กรุงเทพมหานคร
# ...          ...           ...   ...               ...
# 2858180  26780.0    2021-03-14  หญิง          นราธิวาส
# 2858181  27523.0    2021-03-19   ชาย          นราธิวาส
# 2858182  27524.0    2021-03-19   ชาย          นราธิวาส
# 2858183  28377.0    2021-03-25  หญิง          นราธิวาส
# 2858184  28863.0    2021-03-31   ชาย          นราธิวาส
#
#                                                       risk  \
# 2214     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 2215                                           สถานบันเทิง
# 2216                                           สถานบันเทิง
# 2217          ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 2218     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# ...                                                    ...
# 2858180                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2858181                                              อื่นๆ
# 2858182                                              อื่นๆ
# 2858183                                   State Quarantine
# 2858184                                   State Quarantine
#
#         6 ภูมิภาค (ภูมิศาสตร์)        จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  \
# 2214                      กลาง  กรุงเทพมหานคร           95233           86233
# 2215                      กลาง  กรุงเทพมหานคร           95233           86233
# 2216                      กลาง  กรุงเทพมหานคร           95233           86233
# 2217                      กลาง  กรุงเทพมหานคร           95233           86233
# 2218                      กลาง  กรุงเทพมหานคร           95233           86233
# ...                        ...            ...             ...             ...
# 2858180                    ใต้       นราธิวาส            2253            2671
# 2858181                    ใต้       นราธิวาส            2253            2671
# 2858182                    ใต้       นราธิวาส            2253            2671
# 2858183                    ใต้       นราธิวาส            2253            2671
# 2858184                    ใต้       นราธิวาส            2253            2671
#
#          จำนวนคนปี 2662  จำนวนคนปี 2563  จำนวนคนปี 2564
# 2214              91392          221048           97607
# 2215              91392          221048           97607
# 2216              91392          221048           97607
# 2217              91392          221048           97607
# 2218              91392          221048           97607
# ...                 ...             ...             ...
# 2858180            2509            2804            3289
# 2858181            2509            2804            3289
# 2858182            2509            2804            3289
# 2858183            2509            2804            3289
# 2858184            2509            2804            3289
#
# [19799 rows x 12 columns]

# %%
covid_3 = covid2[(covid2['announce_date'] >='2021-04-01') & (covid2['announce_date'] <='2021-06-30')]   
covid_3
# Out:
#               No. announce_date   sex province_of_onset  \
# 4318      28875.0    2021-04-01  หญิง     กรุงเทพมหานคร
# 4319      28876.0    2021-04-01   ชาย     กรุงเทพมหานคร
# 4320      28877.0    2021-04-01   ชาย     กรุงเทพมหานคร
# 4321      28878.0    2021-04-01   ชาย     กรุงเทพมหานคร
# 4322      28879.0    2021-04-01  หญิง     กรุงเทพมหานคร
# ...           ...           ...   ...               ...
# 2860337  256987.0    2021-06-30   ชาย          นราธิวาส
# 2860338  256988.0    2021-06-30  หญิง          นราธิวาส
# 2860339  256989.0    2021-06-30   ชาย          นราธิวาส
# 2860340  256990.0    2021-06-30   ชาย          นราธิวาส
# 2860341  256991.0    2021-06-30   ชาย          นราธิวาส
#
#                                                      risk  \
# 4318                                     State Quarantine
# 4319          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4320          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4321                                 Cluster ผับ Thonglor
# 4322                                     State Quarantine
# ...                                                   ...
# 2860337                                             อื่นๆ
# 2860338                                             อื่นๆ
# 2860339  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
# 2860340  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
# 2860341  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
#
#         6 ภูมิภาค (ภูมิศาสตร์)        จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  \
# 4318                      กลาง  กรุงเทพมหานคร           95233           86233
# 4319                      กลาง  กรุงเทพมหานคร           95233           86233
# 4320                      กลาง  กรุงเทพมหานคร           95233           86233
# 4321                      กลาง  กรุงเทพมหานคร           95233           86233
# 4322                      กลาง  กรุงเทพมหานคร           95233           86233
# ...                        ...            ...             ...             ...
# 2860337                    ใต้       นราธิวาส            2253            2671
# 2860338                    ใต้       นราธิวาส            2253            2671
# 2860339                    ใต้       นราธิวาส            2253            2671
# 2860340                    ใต้       นราธิวาส            2253            2671
# 2860341                    ใต้       นราธิวาส            2253            2671
#
#          จำนวนคนปี 2662  จำนวนคนปี 2563  จำนวนคนปี 2564
# 4318              91392          221048           97607
# 4319              91392          221048           97607
# 4320              91392          221048           97607
# 4321              91392          221048           97607
# 4322              91392          221048           97607
# ...                 ...             ...             ...
# 2860337            2509            2804            3289
# 2860338            2509            2804            3289
# 2860339            2509            2804            3289
# 2860340            2509            2804            3289
# 2860341            2509            2804            3289
#
# [191645 rows x 12 columns]

# %%
covid_4 = covid2[(covid2['announce_date'] >='2021-07-01') &  (covid2['announce_date'] <= '2021-07-31')]    
covid_4
# Out:
#               No. announce_date   sex province_of_onset  \
# 70700    259637.0    2021-07-01  หญิง     กรุงเทพมหานคร
# 70701    259638.0    2021-07-01  หญิง     กรุงเทพมหานคร
# 70702    259639.0    2021-07-01  หญิง     กรุงเทพมหานคร
# 70703    259640.0    2021-07-01   ชาย     กรุงเทพมหานคร
# 70704    259641.0    2021-07-01  หญิง     กรุงเทพมหานคร
# ...           ...           ...   ...               ...
# 2864440  592801.0    2021-07-31   ชาย          นราธิวาส
# 2864441  592802.0    2021-07-31  หญิง          นราธิวาส
# 2864442  592803.0    2021-07-31   ชาย          นราธิวาส
# 2864443  592804.0    2021-07-31   ชาย          นราธิวาส
# 2864444  592805.0    2021-07-31   ชาย          นราธิวาส
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 70700    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 70701    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 70702    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 70703    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 70704    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# ...                                              ...                    ...
# 2864440  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2864441  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2864442  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2864443  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2864444  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 70700    กรุงเทพมหานคร           95233           86233           91392
# 70701    กรุงเทพมหานคร           95233           86233           91392
# 70702    กรุงเทพมหานคร           95233           86233           91392
# 70703    กรุงเทพมหานคร           95233           86233           91392
# 70704    กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2864440       นราธิวาส            2253            2671            2509
# 2864441       นราธิวาส            2253            2671            2509
# 2864442       นราธิวาส            2253            2671            2509
# 2864443       นราธิวาส            2253            2671            2509
# 2864444       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 70700            221048           97607
# 70701            221048           97607
# 70702            221048           97607
# 70703            221048           97607
# 70704            221048           97607
# ...                 ...             ...
# 2864440            2804            3289
# 2864441            2804            3289
# 2864442            2804            3289
# 2864443            2804            3289
# 2864444            2804            3289
#
# [310510 rows x 12 columns]

# %%
covid_5 = covid2[(covid2['announce_date'] >='2021-08-01') &  (covid2['announce_date'] <= '2021-08-15')]   
covid_5
# Out:
#               No. announce_date   sex province_of_onset  \
# 154700   597493.0    2021-08-01  หญิง     กรุงเทพมหานคร
# 154701   597494.0    2021-08-01   ชาย     กรุงเทพมหานคร
# 154702   597495.0    2021-08-01  หญิง     กรุงเทพมหานคร
# 154703   597503.0    2021-08-01   ชาย     กรุงเทพมหานคร
# 154704   597545.0    2021-08-01   ชาย     กรุงเทพมหานคร
# ...           ...           ...   ...               ...
# 2867674  902260.0    2021-08-15   ชาย          นราธิวาส
# 2867675  902261.0    2021-08-15  หญิง          นราธิวาส
# 2867676  902262.0    2021-08-15  หญิง          นราธิวาส
# 2867677  902263.0    2021-08-15  หญิง          นราธิวาส
# 2867678  902264.0    2021-08-15  หญิง          นราธิวาส
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 154700                                         อื่นๆ                   กลาง
# 154701                                         อื่นๆ                   กลาง
# 154702                                         อื่นๆ                   กลาง
# 154703                                         อื่นๆ                   กลาง
# 154704                                         อื่นๆ                   กลาง
# ...                                              ...                    ...
# 2867674  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2867675  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2867676              บุคลากรด้านการแพทย์และสาธารณสุข                    ใต้
# 2867677                                        อื่นๆ                    ใต้
# 2867678                                        อื่นๆ                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 154700   กรุงเทพมหานคร           95233           86233           91392
# 154701   กรุงเทพมหานคร           95233           86233           91392
# 154702   กรุงเทพมหานคร           95233           86233           91392
# 154703   กรุงเทพมหานคร           95233           86233           91392
# 154704   กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2867674       นราธิวาส            2253            2671            2509
# 2867675       นราธิวาส            2253            2671            2509
# 2867676       นราธิวาส            2253            2671            2509
# 2867677       นราธิวาส            2253            2671            2509
# 2867678       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 154700           221048           97607
# 154701           221048           97607
# 154702           221048           97607
# 154703           221048           97607
# 154704           221048           97607
# ...                 ...             ...
# 2867674            2804            3289
# 2867675            2804            3289
# 2867676            2804            3289
# 2867677            2804            3289
# 2867678            2804            3289
#
# [274251 rows x 12 columns]

# %%
covid_11 = covid2[(covid2['announce_date'] >='2021-08-16') &  (covid2['announce_date'] <= '2021-08-31')]   
covid_11
# Out:
#                No. announce_date          sex province_of_onset  \
# 214987    907198.0    2021-08-16          ชาย     กรุงเทพมหานคร
# 214988    907228.0    2021-08-16         หญิง     กรุงเทพมหานคร
# 214989    907235.0    2021-08-16          ชาย     กรุงเทพมหานคร
# 214990    908326.0    2021-08-16          ชาย     กรุงเทพมหานคร
# 214991    908327.0    2021-08-16         หญิง     กรุงเทพมหานคร
# ...            ...           ...          ...               ...
# 2871150  1199708.0    2021-08-31         หญิง          นราธิวาส
# 2871151  1199709.0    2021-08-31         หญิง          นราธิวาส
# 2871152  1199710.0    2021-08-31         หญิง          นราธิวาส
# 2871153  1199759.0    2021-08-31         หญิง          นราธิวาส
# 2871154  1200771.0    2021-08-31  ไม่มีข้อมูล          นราธิวาส
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 214987                                         อื่นๆ                   กลาง
# 214988                                         อื่นๆ                   กลาง
# 214989                                         อื่นๆ                   กลาง
# 214990                                    ระบุไม่ได้                   กลาง
# 214991   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# ...                                              ...                    ...
# 2871150  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2871151  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2871152  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2871153  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2871154                                        อื่นๆ                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 214987   กรุงเทพมหานคร           95233           86233           91392
# 214988   กรุงเทพมหานคร           95233           86233           91392
# 214989   กรุงเทพมหานคร           95233           86233           91392
# 214990   กรุงเทพมหานคร           95233           86233           91392
# 214991   กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2871150       นราธิวาส            2253            2671            2509
# 2871151       นราธิวาส            2253            2671            2509
# 2871152       นราธิวาส            2253            2671            2509
# 2871153       นราธิวาส            2253            2671            2509
# 2871154       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 214987           221048           97607
# 214988           221048           97607
# 214989           221048           97607
# 214990           221048           97607
# 214991           221048           97607
# ...                 ...             ...
# 2871150            2804            3289
# 2871151            2804            3289
# 2871152            2804            3289
# 2871153            2804            3289
# 2871154            2804            3289
#
# [240362 rows x 12 columns]

# %%
covid_6 = covid2[(covid2['announce_date'] >='2021-09-01') &  (covid2['announce_date'] <='2021-09-30')]     
covid_6
# Out:
#                No. announce_date          sex province_of_onset  \
# 276942   1205696.0    2021-09-01          ชาย     กรุงเทพมหานคร
# 276943   1205697.0    2021-09-01          ชาย     กรุงเทพมหานคร
# 276944   1205698.0    2021-09-01         หญิง     กรุงเทพมหานคร
# 276945   1205699.0    2021-09-01         หญิง     กรุงเทพมหานคร
# 276946   1205700.0    2021-09-01         หญิง     กรุงเทพมหานคร
# ...            ...           ...          ...               ...
# 2881650  1601590.0    2021-09-30          ชาย          นราธิวาส
# 2881651  1601689.0    2021-09-30          ชาย          นราธิวาส
# 2881652  1601690.0    2021-09-30         หญิง          นราธิวาส
# 2881653  1601691.0    2021-09-30          ชาย          นราธิวาส
# 2881654  1603310.0    2021-09-30  ไม่มีข้อมูล          นราธิวาส
#
#                                                   risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 276942   ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว                   กลาง
# 276943     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 276944                            อยู่ระหว่างการสอบสวน                   กลาง
# 276945   ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว                   กลาง
# 276946   ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว                   กลาง
# ...                                                ...                    ...
# 2881650                                          อื่นๆ                    ใต้
# 2881651    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2881652    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2881653    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2881654                                          อื่นๆ                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 276942   กรุงเทพมหานคร           95233           86233           91392
# 276943   กรุงเทพมหานคร           95233           86233           91392
# 276944   กรุงเทพมหานคร           95233           86233           91392
# 276945   กรุงเทพมหานคร           95233           86233           91392
# 276946   กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2881650       นราธิวาส            2253            2671            2509
# 2881651       นราธิวาส            2253            2671            2509
# 2881652       นราธิวาส            2253            2671            2509
# 2881653       นราธิวาส            2253            2671            2509
# 2881654       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 276942           221048           97607
# 276943           221048           97607
# 276944           221048           97607
# 276945           221048           97607
# 276946           221048           97607
# ...                 ...             ...
# 2881650            2804            3289
# 2881651            2804            3289
# 2881652            2804            3289
# 2881653            2804            3289
# 2881654            2804            3289
#
# [346103 rows x 12 columns]

# %%
covid_7 = covid2[(covid2['announce_date'] >='2021-10-01') &  (covid2['announce_date'] <='2021-10-31')]     
covid_7
# Out:
#                No. announce_date   sex province_of_onset  \
# 354425   1603764.0    2021-10-01   ชาย     กรุงเทพมหานคร
# 354426   1604215.0    2021-10-01  หญิง     กรุงเทพมหานคร
# 354427   1604216.0    2021-10-01  หญิง     กรุงเทพมหานคร
# 354428   1604217.0    2021-10-01   ชาย     กรุงเทพมหานคร
# 354429   1604218.0    2021-10-01  หญิง     กรุงเทพมหานคร
# ...            ...           ...   ...               ...
# 2893563  1909652.0    2021-10-31  หญิง          นราธิวาส
# 2893564  1909953.0    2021-10-31   ชาย          นราธิวาส
# 2893565  1909954.0    2021-10-31  หญิง          นราธิวาส
# 2893566  1909955.0    2021-10-31  หญิง          นราธิวาส
# 2893567  1911103.0    2021-10-31  หญิง          นราธิวาส
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 354425                                         อื่นๆ                   กลาง
# 354426   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 354427   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 354428   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 354429   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# ...                                              ...                    ...
# 2893563                                        อื่นๆ                    ใต้
# 2893564                                        อื่นๆ                    ใต้
# 2893565                                        อื่นๆ                    ใต้
# 2893566                                        อื่นๆ                    ใต้
# 2893567  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 354425   กรุงเทพมหานคร           95233           86233           91392
# 354426   กรุงเทพมหานคร           95233           86233           91392
# 354427   กรุงเทพมหานคร           95233           86233           91392
# 354428   กรุงเทพมหานคร           95233           86233           91392
# 354429   กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2893563       นราธิวาส            2253            2671            2509
# 2893564       นราธิวาส            2253            2671            2509
# 2893565       นราธิวาส            2253            2671            2509
# 2893566       นราธิวาส            2253            2671            2509
# 2893567       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 354425           221048           97607
# 354426           221048           97607
# 354427           221048           97607
# 354428           221048           97607
# 354429           221048           97607
# ...                 ...             ...
# 2893563            2804            3289
# 2893564            2804            3289
# 2893565            2804            3289
# 2893566            2804            3289
# 2893567            2804            3289
#
# [274738 rows x 12 columns]

# %%
covid_8 = covid2[(covid2['announce_date'] >='2022-01-01') &  (covid2['announce_date'] <='2022-01-31')] 
covid_8
# Out:
#                No. announce_date   sex province_of_onset   risk  \
# 419716   2223462.0    2022-01-01  หญิง     กรุงเทพมหานคร  อื่นๆ
# 419717   2223463.0    2022-01-01  หญิง     กรุงเทพมหานคร  อื่นๆ
# 419718   2223817.0    2022-01-01  หญิง     กรุงเทพมหานคร  อื่นๆ
# 419719   2223818.0    2022-01-01   ชาย     กรุงเทพมหานคร  อื่นๆ
# 419720   2223819.0    2022-01-01  หญิง     กรุงเทพมหานคร  อื่นๆ
# ...            ...           ...   ...               ...    ...
# 2899970  2439180.0    2022-01-31  หญิง          นราธิวาส  อื่นๆ
# 2899971  2439181.0    2022-01-31   ชาย          นราธิวาส  อื่นๆ
# 2899972  2439182.0    2022-01-31  หญิง          นราธิวาส  อื่นๆ
# 2899973  2439183.0    2022-01-31  หญิง          นราธิวาส  อื่นๆ
# 2899974  2439184.0    2022-01-31   ชาย          นราธิวาส  อื่นๆ
#
#         6 ภูมิภาค (ภูมิศาสตร์)        จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  \
# 419716                    กลาง  กรุงเทพมหานคร           95233           86233
# 419717                    กลาง  กรุงเทพมหานคร           95233           86233
# 419718                    กลาง  กรุงเทพมหานคร           95233           86233
# 419719                    กลาง  กรุงเทพมหานคร           95233           86233
# 419720                    กลาง  กรุงเทพมหานคร           95233           86233
# ...                        ...            ...             ...             ...
# 2899970                    ใต้       นราธิวาส            2253            2671
# 2899971                    ใต้       นราธิวาส            2253            2671
# 2899972                    ใต้       นราธิวาส            2253            2671
# 2899973                    ใต้       นราธิวาส            2253            2671
# 2899974                    ใต้       นราธิวาส            2253            2671
#
#          จำนวนคนปี 2662  จำนวนคนปี 2563  จำนวนคนปี 2564
# 419716            91392          221048           97607
# 419717            91392          221048           97607
# 419718            91392          221048           97607
# 419719            91392          221048           97607
# 419720            91392          221048           97607
# ...                 ...             ...             ...
# 2899970            2509            2804            3289
# 2899971            2509            2804            3289
# 2899972            2509            2804            3289
# 2899973            2509            2804            3289
# 2899974            2509            2804            3289
#
# [193400 rows x 12 columns]

# %%
covid_9 = covid2[(covid2['announce_date'] >='2022-02-01') &  (covid2['announce_date'] <='2022-02-28')] 
covid_9
# Out:
#                No. announce_date          sex province_of_onset  \
# 450874   2441170.0    2022-02-01         หญิง     กรุงเทพมหานคร
# 450875   2441411.0    2022-02-01         หญิง     กรุงเทพมหานคร
# 450876   2441412.0    2022-02-01          ชาย     กรุงเทพมหานคร
# 450877   2441414.0    2022-02-01          ชาย     กรุงเทพมหานคร
# 450878   2441415.0    2022-02-01         หญิง     กรุงเทพมหานคร
# ...            ...           ...          ...               ...
# 2901685  2888434.0    2022-02-28         หญิง          นราธิวาส
# 2901686  2888618.0    2022-02-28          ชาย          นราธิวาส
# 2901687  2888632.0    2022-02-28          ชาย          นราธิวาส
# 2901688  2888904.0    2022-02-28         หญิง          นราธิวาส
# 2901689  2889472.0    2022-02-28  ไม่มีข้อมูล          นราธิวาส
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 450874   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 450875   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 450876   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 450877   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 450878                                         อื่นๆ                   กลาง
# ...                                              ...                    ...
# 2901685              บุคลากรด้านการแพทย์และสาธารณสุข                    ใต้
# 2901686                         อยู่ระหว่างการสอบสวน                    ใต้
# 2901687                         อยู่ระหว่างการสอบสวน                    ใต้
# 2901688                                    สถานศึกษา                    ใต้
# 2901689                                        อื่นๆ                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 450874   กรุงเทพมหานคร           95233           86233           91392
# 450875   กรุงเทพมหานคร           95233           86233           91392
# 450876   กรุงเทพมหานคร           95233           86233           91392
# 450877   กรุงเทพมหานคร           95233           86233           91392
# 450878   กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2901685       นราธิวาส            2253            2671            2509
# 2901686       นราธิวาส            2253            2671            2509
# 2901687       นราธิวาส            2253            2671            2509
# 2901688       นราธิวาส            2253            2671            2509
# 2901689       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 450874           221048           97607
# 450875           221048           97607
# 450876           221048           97607
# 450877           221048           97607
# 450878           221048           97607
# ...                 ...             ...
# 2901685            2804            3289
# 2901686            2804            3289
# 2901687            2804            3289
# 2901688            2804            3289
# 2901689            2804            3289
#
# [398631 rows x 12 columns]

# %%
covid_10 = covid2[(covid2['announce_date'] >='2022-03-01') &  (covid2['announce_date'] <='2022-03-18')] 
covid_10
# Out:
#                No. announce_date          sex province_of_onset  \
# 519657   2892218.0    2022-03-01         หญิง     กรุงเทพมหานคร
# 519658   2894131.0    2022-03-01          ชาย     กรุงเทพมหานคร
# 519659   2894220.0    2022-03-01         หญิง     กรุงเทพมหานคร
# 519660   2894221.0    2022-03-01         หญิง     กรุงเทพมหานคร
# 519661   2894222.0    2022-03-01         หญิง     กรุงเทพมหานคร
# ...            ...           ...          ...               ...
# 2904754  3297872.0    2022-03-18          ชาย          นราธิวาส
# 2904755  3298018.0    2022-03-18          ชาย          นราธิวาส
# 2904756  3298348.0    2022-03-18          ชาย          นราธิวาส
# 2904757  3300146.0    2022-03-18  ไม่มีข้อมูล          นราธิวาส
# 2904758  3300379.0    2022-03-18  ไม่มีข้อมูล          นราธิวาส
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 519657   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 519658                                         อื่นๆ                   กลาง
# 519659                                         อื่นๆ                   กลาง
# 519660                                         อื่นๆ                   กลาง
# 519661               บุคลากรด้านการแพทย์และสาธารณสุข                   กลาง
# ...                                              ...                    ...
# 2904754                                        อื่นๆ                    ใต้
# 2904755  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                    ใต้
# 2904756                         อยู่ระหว่างการสอบสวน                    ใต้
# 2904757                                        อื่นๆ                    ใต้
# 2904758                                        อื่นๆ                    ใต้
#
#                จังหวัด  จำนวนคนปี 2560  จำนวนคนปี 2561  จำนวนคนปี 2662  \
# 519657   กรุงเทพมหานคร           95233           86233           91392
# 519658   กรุงเทพมหานคร           95233           86233           91392
# 519659   กรุงเทพมหานคร           95233           86233           91392
# 519660   กรุงเทพมหานคร           95233           86233           91392
# 519661   กรุงเทพมหานคร           95233           86233           91392
# ...                ...             ...             ...             ...
# 2904754       นราธิวาส            2253            2671            2509
# 2904755       นราธิวาส            2253            2671            2509
# 2904756       นราธิวาส            2253            2671            2509
# 2904757       นราธิวาส            2253            2671            2509
# 2904758       นราธิวาส            2253            2671            2509
#
#          จำนวนคนปี 2563  จำนวนคนปี 2564
# 519657           221048           97607
# 519658           221048           97607
# 519659           221048           97607
# 519660           221048           97607
# 519661           221048           97607
# ...                 ...             ...
# 2904754            2804            3289
# 2904755            2804            3289
# 2904756            2804            3289
# 2904757            2804            3289
# 2904758            2804            3289
#
# [366848 rows x 12 columns]

# %%
#covid_1.to_csv(os.path.join(path,'covid_1.csv'))
#covid_2.to_csv(os.path.join(path,'covid_2.csv'))
#covid_3.to_csv(os.path.join(path,'covid_3.csv'))
#covid_4.to_csv(os.path.join(path,'covid_4.csv'))
covid_5.to_csv(os.path.join(path,'covid_5.csv'))
#covid_6.to_csv(os.path.join(path,'covid_6.csv'))
#covid_7.to_csv(os.path.join(path,'covid_7.csv'))
#covid_8.to_csv(os.path.join(path,'covid_8.csv'))
#covid_9.to_csv(os.path.join(path,'covid_9.csv'))
#covid_10.to_csv(os.path.join(path,'covid_10.csv'))
covid_11.to_csv(os.path.join(path,'covid_11.csv'))
